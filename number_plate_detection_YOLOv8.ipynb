# %% [markdown]
# <a href="https://colab.research.google.com/github/sakshigajjar/License-Plate-Detection-using-YOLOv8/blob/main/number_plate_detection_YOLOv8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from IPython.display import Image

# %%
# !git clone https://github.com/MuhammadMoinFaisal/Automatic_Number_Plate_Detection_Recognition_YOLOv8.git
# Out:
# fatal: destination path 'Automatic_Number_Plate_Detection_Recognition_YOLOv8' already exists and is not an empty directory.

# %%
# !pwd
# Out:
# /content

# %%
# %cd /content/Automatic_Number_Plate_Detection_Recognition_YOLOv8/ultralytics/yolo/v8/detect
# Out:
# /content/Automatic_Number_Plate_Detection_Recognition_YOLOv8/ultralytics/yolo/v8/detect

# %%
# !pip install -e '.[dev]'
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Obtaining file:///content/Automatic_Number_Plate_Detection_Recognition_YOLOv8/ultralytics/yolo/v8/detect
# ERROR: file:///content/Automatic_Number_Plate_Detection_Recognition_YOLOv8/ultralytics/yolo/v8/detect does not appear to be a Python project: neither 'setup.py' nor 'pyproject.toml' found.

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="kyiTZ6hy37MgXNprlfhy")
project = rf.workspace("college-ygeyo").project("number_plate-jd285")
dataset = project.version(1).download("yolov8")
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# [WARNING] we noticed you are downloading a `yolov8` datasets but you don't have `ultralytics` installed. Roboflow `.deploy` supports only models trained with `ultralytics<=8.0.20`, to intall it `pip install ultralytics<=8.0.20`.
# ...
# Extracting Dataset Version Zip to Number_plate-1 in yolov8:: 100%|██████████| 80/80 [00:00<00:00, 1507.96it/s]

# %%
HOME='/content/Automatic_Number_Plate_Detection_Recognition_YOLOv8/ultralytics/yolo/v8/detect'

# %%
# %cd {HOME}
# Out:
# /content/Automatic_Number_Plate_Detection_Recognition_YOLOv8/ultralytics/yolo/v8/detect

# %%
# %cd {dataset.location}
# Out:
# /content/Automatic_Number_Plate_Detection_Recognition_YOLOv8/ultralytics/yolo/v8/detect/Number_plate-1

# %%
# %cd {HOME}

# !python train.py model=yolov8m.pt data={dataset.location}/data.yaml epochs=120 imgsz=320
# Out:
# /content/Automatic_Number_Plate_Detection_Recognition_YOLOv8/ultralytics/yolo/v8/detect
# Traceback (most recent call last):
#   File "/content/Automatic_Number_Plate_Detection_Recognition_YOLOv8/ultralytics/yolo/v8/detect/train.py", line 5, in <module>
#     import hydra
# ModuleNotFoundError: No module named 'hydra'

# %%
# !ls /content/Automatic_Number_Plate_Detection_Recognition_YOLOv8/ultralytics/yolo/v8/detect/runs/detect/train
# Out:
# args.yaml					    train_batch0.jpg
# confusion_matrix.png				    train_batch1.jpg
# events.out.tfevents.1682420105.9a118e1bb69c.1575.0  train_batch220.jpg
# F1_curve.png					    train_batch221.jpg
# P_curve.png					    train_batch222.jpg
# PR_curve.png					    train_batch2.jpg
# predictions.json				    val_batch0_labels.jpg
# R_curve.png					    val_batch0_pred.jpg
# results.csv					    weights
# results.png

# %%
Image(filename='/content/Automatic_Number_Plate_Detection_Recognition_YOLOv8/ultralytics/yolo/v8/detect/runs/detect/train/confusion_matrix.png')

# %%
Image(filename=r'/content/Automatic_Number_Plate_Detection_Recognition_YOLOv8/ultralytics/yolo/v8/detect/runs/detect/train/results.png',width=600)

# %%
Image(filename=r'/content/Automatic_Number_Plate_Detection_Recognition_YOLOv8/ultralytics/yolo/v8/detect/runs/detect/train/val_batch0_pred.jpg',width=600)

# %%
# %ls /content/Automatic_Number_Plate_Detection_Recognition_YOLOv8/ultralytics/yolo/v8/detect/runs/detect/train/weights
# Out:
# best.pt  last.pt

# %%
# !python val.py model='/content/Automatic_Number_Plate_Detection_Recognition_YOLOv8/ultralytics/yolo/v8/detect/runs/detect/train/weights/best.pt' data={dataset.location}/data.yaml
# Out:
# 2023-04-25 12:27:28.508063: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-04-25 12:27:31.606556: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Ultralytics YOLOv8.0.3 🚀 Python-3.9.16 torch-2.0.0+cu118 CPU
# Fusing layers...
# Model summary: 218 layers, 25840339 parameters, 0 gradients, 78.7 GFLOPs
# val: Scanning /content/Automatic_Number_Plate_Detection_Recognition_YOLOv8/ultralytics/yolo/v8/detect/Number_plate-1/valid/labels.cache... 3 images, 0 backgrounds, 0 corrupt: 100% 3/3 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:06<00:00,  6.29s/it]
# ...

# %%
# !pip install easyocr
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/2.9 MB 55.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 608.2/608.2 kB 33.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 146.0/146.0 kB 15.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.6/47.6 MB 13.9 MB/s eta 0:00:00
# ...
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.7.0.72
#     Uninstalling opencv-python-headless-4.7.0.72:
#       Successfully uninstalled opencv-python-headless-4.7.0.72
# ...

# %%
# !gdown "https://drive.google.com/uc?id=1P-oVR0J35Dw40lzw47sE19oADSW-tyb1&confirm=t"
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1P-oVR0J35Dw40lzw47sE19oADSW-tyb1&confirm=t
# To: /content/Automatic_Number_Plate_Detection_Recognition_YOLOv8/ultralytics/yolo/v8/detect/demo.mp4
# 100% 9.56M/9.56M [00:00<00:00, 55.7MB/s]

# %%
# !python predict.py model='/content/Automatic_Number_Plate_Detection_Recognition_YOLOv8/ultralytics/yolo/v8/detect/runs/detect/train/weights/best.pt' source='B1_s2.mp4'
# Out:
# CUDA not available - defaulting to CPU. Note: This module is much faster with a GPU.
# CUDA not available - defaulting to CPU. Note: This module is much faster with a GPU.
# 2023-04-25 14:38:58.967865: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-04-25 14:39:00.198501: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Ultralytics YOLOv8.0.3 🚀 Python-3.9.16 torch-2.0.0+cu118 CPU
# Fusing layers...
# Model summary: 218 layers, 25840339 parameters, 0 gradients, 78.7 GFLOPs
# video 1/1 (1/990) /content/Automatic_Number_Plate_Detection_Recognition_YOLOv8/ultralytics/yolo/v8/detect/B1_s2.mp4: 640x384 1 plate, 1031.4ms
# ...
